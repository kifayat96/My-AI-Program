# %% [markdown]
# <a href="https://colab.research.google.com/github/kifayat96/My-AI-Program/blob/main/list23.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
countryName=["pakistan","iran","india","china"]
print(countryName)
# Out:
# ['pakistan', 'iran', 'india', 'china']

# %%
countryName.append("iraq")

# %%
print(countryName)
# Out:
# ['pakistan', 'iran', 'india', 'china', 'iraq']
