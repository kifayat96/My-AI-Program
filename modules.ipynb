# %% [markdown]
# <a href="https://colab.research.google.com/github/kifayat96/My-AI-Program/blob/main/modules.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import math
print(math.sqrt(66))
# Out:
# 8.12403840463596

# %%
from math import sqrt
print(sqrt(60))
# Out:
# 7.745966692414834
