# %% [markdown]
# <a href="https://colab.research.google.com/github/kifayat96/My-AI-Program/blob/main/Day3_Python_Basics.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# My first AI Journey code
print("Hellow I am Kifayat Ullah")
print("I am an AI Student")

name="Kifayat Ullah"
Semester=6
University = "The University of Agticluture Peshawar"

print(f"name:{name}")
print(f"semester:{Semester}")
print(f"University:{University}")

#Simple task
list=['Python','machine learning','Deep learning','Computer Vision','NLP']

print("\n My AI skills")
print(list)
# Out:
# Hellow I am Kifayat Ullah
# I am an AI Student
# name:Kifayat Ullah
# semester:6
# University:The University of Agticluture Peshawar
#
#  My AI skills
# ['Python', 'machine learning', 'Deep learning', 'Computer Vision', 'NLP']
