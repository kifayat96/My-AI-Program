# %% [markdown]
# <a href="https://colab.research.google.com/github/kifayat96/My-AI-Program/blob/main/prictice.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 1. creat a list of 5 numbers and add one more numbe

# %%
numbers=[1,2,3,4,5]

# %%
print(numbers)
# Out:
# [1, 2, 3, 4, 5]

# %%
numbers.append(7)

# %%
print(numbers)
# Out:
# [1, 2, 3, 4, 5, 7]

# %% [markdown]
# 2.creat a tuple of 3 cities and print the secound city

# %%
citys=("peshawr","karachi","hyderabad")
print(citys[1])
# Out:
# karachi

# %% [markdown]
# 3.creat two sets and find their intersection.

# %%
set1={2,8,9,4,6}
set2={8,9,10}
print(set1.intersection(set2))
# Out:
# {8, 9}

# %% [markdown]
# 4.creat a dictionaary of your own details and print all keys

# %%
student={
    "name":"kiayat ullah",
    "age":24,
    "gender":"male",
    "city":"buner",
    "student":"BS AI"
}

# %%
print(student.keys())
# Out:
# dict_keys(['name', 'age', 'gender', 'city', 'student'])
