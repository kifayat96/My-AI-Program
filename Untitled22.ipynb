# %% [markdown]
# <a href="https://colab.research.google.com/github/kifayat96/My-AI-Program/blob/main/Untitled22.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
num1=[1,2,3,4,5]
num2=[6,7,8,9]
print(num1+num2)
# Out:
# [1, 2, 3, 4, 5, 6, 7, 8, 9]
